# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
soccer2007 = pd.read_csv("Untitled Folder/soccer2007.csv")
soccer2008 = pd.read_csv("Untitled Folder/soccer2008.csv")
soccer2009 = pd.read_csv("Untitled Folder/soccer2009.csv")
soccer2010 = pd.read_csv("Untitled Folder/soccer2010.csv")
soccer2011 = pd.read_csv("Untitled Folder/soccer2011.csv")
soccer2012 = pd.read_csv("Untitled Folder/soccer2012.csv")
soccer2013 = pd.read_csv("Untitled Folder/soccer2013.csv")
soccer2014 = pd.read_csv("Untitled Folder/soccer2014.csv")
soccer2015 = pd.read_csv("Untitled Folder/soccer2015.csv")
soccer2016 = pd.read_csv("Untitled Folder/soccer2016.csv")
soccer2017 = pd.read_csv("Untitled Folder/soccer2017.csv")

# %%
soccer2007
# Out:
#     club     last_name  first_name position  base_salary  \
# 0    CHI         Armas       Chris        M     225000.0
# 1    CHI        Banner     Michael        M      12900.0
# 2    CHI       Barrett        Chad        F      41212.5
# 3    CHI        Blanco  Cuauhtemoc        F    2492316.0
# 4    CHI         Brown        C.J.        D     106391.0
# ..   ...           ...         ...      ...          ...
# 366  TFC        Samuel      Collin        F      90000.0
# 367  TFC  Stamatopolus       Kenny       GK      30000.0
# 368  TFC        Sutton        Greg       GK     125000.0
# 369  TFC         Welsh      Andrew        M     195000.0
# 370  TFC         Wynne     Marvell        D      47500.0
#
#      guaranteed_compensation
# 0                   225000.0
# 1                    12900.0
# 2                    48712.5
# 3                  2666778.0
# 4                   106391.0
# ..                       ...
# 366                 115000.0
# 367                  37500.0
# ...

# %% [markdown]
# 2007 YILI İÇİN

# %%
#2007 datalist rows.
row_sayısı2007 = len(soccer2007.index)

#2007 MAKSİMUM MAAŞ
maks_maas2007 = soccer2007["base_salary"].max()

#2007 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2007 = soccer2007.max()

#2007 GENEL MAAŞ ORTALAMASI
maaş_ortalama2007 = soccer2007["base_salary"].mean()

#2007 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2007 = soccer2007.groupby("position").mean()

#2007 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2007 = soccer2007["position"].value_counts()

#2007 TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2007 = soccer2007["club"].value_counts()

#2007 MAKS TAZMİNAT   soccer2007[soccer2007["guaranteed_compensation"] == soccer2007["guaranteed_compensation"].max()]
tazminat_2007 = soccer2007["guaranteed_compensation"].max()

#2007 MİN MAAŞ
min_maas2007 = soccer2007["base_salary"].min()

# %% [markdown]
# 2008 YILI İÇİN

# %%
#2008 datalist rows.
row_sayısı2008 = len(soccer2008.index)

#2008 MAKSİMUM MAAŞ
maks_maas2008 = soccer2008["base_salary"].max()

#2008 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2008 = soccer2008.max()

#2008 GENEL MAAŞ ORTALAMASI
maas_ortalama2008 = soccer2008["base_salary"].mean()

#2008 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2008 = soccer2008.groupby("position").mean()

#2008 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2008 = soccer2008["position"].value_counts()

#2008 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2008 = soccer2008["club"].value_counts()

#2008 MAKS TAZMİNAT
tazminat_2008 = soccer2008["guaranteed_compensation"].max()

#2008 MİN MAAŞ
min_maas2008 = soccer2008["base_salary"].min()

# %% [markdown]
# 2009 YILI İÇİN

# %%
#2009 datalist rows.
row_sayısı2009 = len(soccer2009.index)

#2009 MAKSİMUM MAAŞ
maks_maas2009 = soccer2009["base_salary"].max()

#2009 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2009 = soccer2009.max()

#2009 GENEL MAAŞ ORTALAMASI
maas_ortalaması2009 = soccer2009["base_salary"].mean()

#2009 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2009 = soccer2009.groupby("position").mean()

#2009 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2009 = soccer2009["position"].value_counts()

#2009 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2009 = soccer2009["club"].value_counts()

#2009 MAKS TAZMİNAT
tazminat_2009 = soccer2009["guaranteed_compensation"].max()

#2009 MİN MAAŞ
min_maas2009 = soccer2009["base_salary"].min()

# %% [markdown]
# 2010 YILI İÇİN

# %%
#2010 datalist rows.
row_sayısı2010 = len(soccer2010.index)

#2010 MAKSİMUM MAAŞ
maks_maas2010 = soccer2010["base_salary"].max()

#2010 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2010 = soccer2010.max()

#2010 GENEL MAAŞ ORTALAMASI
maas_ortalaması2010 = soccer2010["base_salary"].mean()

#2010 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2010 = soccer2010.groupby("position").mean()

#2010 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2010 = soccer2010["position"].value_counts()

#2010 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2010 = soccer2010["club"].value_counts()

#2010 MAKS TAZMİNAT
tazminat_2010 = soccer2010["guaranteed_compensation"].max()

#2010 MİN MAAŞ
min_maas2010 = soccer2010["base_salary"].min()

# %% [markdown]
# 2011 YILI İÇİN

# %%
#2011 datalist rows.
row_sayısı2011 = len(soccer2011.index)

#2011 MAKSİMUM MAAŞ
maks_maas2011 = soccer2011["base_salary"].max()

#2011 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2011 = soccer2011[soccer2011["base_salary"]== soccer2011["base_salary"].max()]

#2011 GENEL MAAŞ ORTALAMASI
maas_ortalaması2011 = soccer2011["base_salary"].mean()

#2011 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2011 = soccer2011.groupby("position").mean()

#2011 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2011 = soccer2011["position"].value_counts()

#2011 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2011 = soccer2011["club"].value_counts()

#2011 MAKS TAZMİNAT
tazminat_2011 = soccer2011["guaranteed_compensation"].max()

#2011 MİN MAAŞ
min_maas2011 = soccer2011["base_salary"].min()

# %% [markdown]
# 2012 YILI İÇİN

# %%
#2012 datalist rows.
row_sayısı2012 = len(soccer2012.index)

#2012 MAKSİMUM MAAŞ
maks_maas2012 = soccer2012["base_salary"].max()

#2012 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2012 = soccer2012[soccer2012["base_salary"]== soccer2012["base_salary"].max()]

#2012 GENEL MAAŞ ORTALAMASI
maas_ortalaması2012 = soccer2012["base_salary"].mean()

#2012 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2012 = soccer2012.groupby("position").mean()

#2012 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2012 = soccer2012["position"].value_counts()

#2012 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2012 = soccer2012["club"].value_counts()

#2012 MAKS TAZMİNAT
tazminat_2012 = soccer2012["guaranteed_compensation"].max()

#2012 MİN MAAŞ
min_maas2012 = soccer2012["base_salary"].min()

# %% [markdown]
# 2013 YILI İÇİN

# %%
#2013 datalist rows.
row_sayısı2013 = len(soccer2013.index)

#2013 MAKSİMUM MAAŞ
maks_maas2013 = soccer2013["base_salary"].max()

#2013 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2013 = soccer2013[soccer2013["base_salary"] == soccer2013["base_salary"].max()]

#2013 GENEL MAAŞ ORTALAMASI
maas_ortalaması2013 = soccer2013["base_salary"].mean()

#2013 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2013 = soccer2013.groupby("position").mean()

#2013 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2013 = soccer2013["position"].value_counts()

#2013 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2013 = soccer2013["club"].value_counts()

#2013 MAKS TAZMİNAT
tazminat_2013 = soccer2013["guaranteed_compensation"].max()

#2013 MİN MAAŞ
min_maas2013 = soccer2013["base_salary"].min()

# %% [markdown]
# 2014 YILI İÇİN

# %%
#2014 datalist rows.
row_sayısı2014 = len(soccer2014.index)

#2014 MAKSİMUM MAAŞ
maks_maas2014 = soccer2014["base_salary"].max()

#2014 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2014 = soccer2014[soccer2014["base_salary"]==soccer2014["base_salary"].max()]

#2014 GENEL MAAŞ ORTALAMASI
maas_ortalaması2014 = soccer2014["base_salary"].mean()

#2014 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2014 = soccer2014.groupby("position").mean()

#2014 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2014 = soccer2014["position"].value_counts()

#2014 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2014 = soccer2014["club"].value_counts()

#2014 MAKS TAZMİNAT
tazminat_2014 = soccer2014["guaranteed_compensation"].max()

#2014 MİN MAAŞ
min_maas2014 = soccer2014["base_salary"].min()

# %% [markdown]
# 2015 YILI İÇİN

# %%
#2015 datalist rows.
row_sayısı2015 = len(soccer2015.index)

#2015 MAKSİMUM MAAŞ
maks_maas2015 = soccer2015["base_salary"].max()

#2015 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2015 = soccer2015[soccer2015["base_salary"] == soccer2015["base_salary"].max()]

#2015 GENEL MAAŞ ORTALAMASI
maas_ortalaması2015 = soccer2015["base_salary"].mean()

#2015 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2015 = soccer2015.groupby("position").mean()

#2015 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2015 = soccer2015["position"].value_counts()

#2015 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2015 = soccer2015["club"].value_counts()

#2015 MAKS TAZMİNAT
tazminat_2015 = soccer2015["guaranteed_compensation"].max()

#2015 MİN MAAŞ
min_maas2015 = soccer2015["base_salary"].min()

# %% [markdown]
# 2016 YILI İÇİN

# %%
#2016 datalist rows.
row_sayısı2016 = len(soccer2016.index)

#2016 MAKSİMUM MAAŞ
maks_maas2016 = soccer2016["base_salary"].max()

#2016 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2016 = soccer2016[soccer2016["base_salary"] == soccer2016["base_salary"].max()]

#2016 GENEL MAAŞ ORTALAMASI
maas_ortalaması2016 = soccer2016["base_salary"].mean()

#2016 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2016 = soccer2016.groupby("position").mean()

#2016 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2016 = soccer2016["position"].value_counts()

#2016 TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2016 = soccer2016["club"].value_counts()

#2016 MAKS TAZMİNAT
tazminat_2016 = soccer2016["guaranteed_compensation"].max()

#2016 MİN MAAŞ
min_maas2016 = soccer2016["base_salary"].min()

# %% [markdown]
# 2017 YILI İÇİN

# %%
#2017 datalist rows.
row_sayısı2017 = len(soccer2017.index)

#2017 MAKSİMUM MAAŞ
maks_maas2017 = soccer2017["base_salary"].max()

#2017 MAKSİMUM MAAŞ ALAN OYUNCU BİLGİLERİ
maks_player2017 = soccer2017[soccer2017["base_salary"] == soccer2017["base_salary"].max()]

#2017 GENEL MAAŞ ORTALAMASI
maas_ortalaması2017 = soccer2017["base_salary"].mean()

#2017 MEVKİ MAAŞ ORTALAMASI
mevki_ortalaması2017 = soccer2017.groupby("position").mean()

#2017 MEVKİLERDEKİ OYUNCU SAYISI
mevki_sayısı2017 = soccer2017["position"].value_counts()

#2017 #TAKIMLARDAKİ OYUNCULAR
takım_oyuncuları2017 = soccer2017["club"].value_counts()

#2017 MAKS TAZMİNAT
tazminat_2017 = soccer2017["guaranteed_compensation"].max()

#2017 MİN MAAŞ
min_maas2017 = soccer2017["base_salary"].min()

# %%
#FİGÜRLER OLUŞTURMA

# %%
#MAKSİMUM ALAN FUTBOLCULARIN MAAŞLARI
fig = plt.figure(figsize = (10,10))
plt.title("2007-2017 Yılları Maksimum Fulbolcu Maasları")
y = [maks_maas2007,maks_maas2008,maks_maas2009,maks_maas2010,maks_maas2011,maks_maas2012,maks_maas2013,maks_maas2014,maks_maas2015,maks_maas2016,maks_maas2017]
x = ["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
plt.plot(x,y,color = "blue",lw = 3, marker = "o", markersize = 5.5,markerfacecolor = "black",markeredgecolor = "black")
plt.xlabel("YIL")
plt.ylabel("ÜCRET (*1000000)")
plt.show()

# %%
#MİNİMUM MAAŞ ALANLAR
figmin = plt.figure(figsize = (10,10))
plt.title("2007-2017 Yılları Minimum Fulbolcu Ücretleri")
y = [min_maas2007,min_maas2008,min_maas2009,min_maas2010,min_maas2011,min_maas2012,min_maas2013,min_maas2014,min_maas2015,min_maas2016,min_maas2017]
x = ["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
plt.plot(x,y,color = "blue",lw = 3, marker = "o", markersize = 5.5,markerfacecolor = "black",markeredgecolor = "black")
plt.xlabel("YIL")
plt.ylabel("ÜCRET")
plt.show()

# %%
#ROW SAYISI
figrow = plt.figure(figsize = (10,10))
plt.title("Dataset Veri Sayısı")
x = ["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
y = [row_sayısı2007,row_sayısı2008,row_sayısı2009,row_sayısı2010,row_sayısı2011,row_sayısı2012,row_sayısı2013,row_sayısı2014,row_sayısı2015,row_sayısı2016,row_sayısı2017]
plt.bar(x,y,color = "purple",lw=2)
plt.xlabel("YILLAR")
plt.ylabel("SATIR")
plt.show()

# %%
genel_mevki = mevki_sayısı2007+mevki_sayısı2008+mevki_sayısı2009+mevki_sayısı2010+mevki_sayısı2011+mevki_sayısı2012+mevki_sayısı2013
+mevki_sayısı2014+mevki_sayısı2015+mevki_sayısı2016+mevki_sayısı2017
# Out:
# D      663.0
# D-M     38.0
# D/F      NaN
# D/M      NaN
# F      463.0
# F-M     18.0
# F/M      4.0
# GK     253.0
# M      771.0
# M-D     25.0
# M-F     56.0
# M/D      NaN
# M/F     10.0
# MF       NaN
# Name: position, dtype: float64

# %%
figmevki = plt.figure(figsize = (10,10))
plt.title("Mevki Oyuncuları Sayısı")
plt.plot(genel_mevki.dropna(),lw = 2,marker = "o",markerfacecolor = "black", markeredgecolor = "black",color = "red")
plt.xlabel("MEVKİLER")
plt.ylabel("SAYISI")
plt.show()

# %%
#YILLARA GÖRE ÜCRET ORTALAMSI
figucret_ort = plt.figure(figsize = (10,10))
plt.title("Yıllara Göre Ücret Ortalaması")
x = ["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
y = [maaş_ortalama2007,maas_ortalama2008,maas_ortalaması2009,maas_ortalaması2010,maas_ortalaması2011
     ,maas_ortalaması2012,maas_ortalaması2013,maas_ortalaması2014,maas_ortalaması2015,maas_ortalaması2016,maas_ortalaması2017]
plt.bar(x,y,color = "deepskyblue")
plt.xlabel("YILLAR")
plt.ylabel("ORTALAMA")
plt.show()

# %%
#TAKIMLADAKİ OYUNCU SAYISI
figtakım = plt.figure(figsize = (10,10))
plt.title("TAKIMLARIN OYUNCU SAYILARI")
y = takım_oyuncuları2007 +takım_oyuncuları2008 + takım_oyuncuları2009 + takım_oyuncuları2010+ takım_oyuncuları2011
+takım_oyuncuları2012+takım_oyuncuları2013+takım_oyuncuları2014+takım_oyuncuları2015+takım_oyuncuları2016+takım_oyuncuları2017
plt.plot(y.dropna(),color = "lime",lw = 2.75, marker = "o", markerfacecolor = "mediumblue", markeredgecolor = "mediumblue")
plt.xlabel("TAKIM KISALTMALARI")
plt.ylabel("TOPLAM OYUNCULARIN SAYISI")
plt.show()

# %%
#MAKSİMUM TAZMİNAT DEĞERLERİ 
firtazminat = plt.figure(figsize = (10,10))
plt.title("Yıllara Göre Maksimum Tazminat Verileri")
x = ["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]
y = [tazminat_2007,tazminat_2008,tazminat_2009,tazminat_2010,tazminat_2011,tazminat_2012,tazminat_2013,tazminat_2014,tazminat_2015,tazminat_2016,tazminat_2017]
plt.bar(x,y,color = "steelblue", ec="purple")
plt.xlabel("YILLAR")
plt.ylabel("TAZMİNAT (*1000000)")
plt.show()

# %%
#MEVKİ ORTALAMASI 
fig_mevkiort = plt.figure(figsize = (10,10))
plt.title("Mevkilerin Genel Ücretleri Ortalaması")
y = mevki_ortalaması2007+mevki_ortalaması2008+mevki_ortalaması2009+mevki_ortalaması2010+mevki_ortalaması2011+mevki_ortalaması2012+mevki_ortalaması2013+mevki_ortalaması2014+mevki_ortalaması2015+mevki_ortalaması2016+mevki_ortalaması2017
plt.plot(y.dropna(),color = "gold",lw=3,marker = "o",markeredgecolor="black",markerfacecolor="black")
plt.xlabel("MEVKİLER")
plt.ylabel("ORTALAMA ÜCRETLER")
plt.show()

# %%
kisi2007 = soccer2007[soccer2007["base_salary"] == soccer2007["base_salary"].max()]["last_name"].iloc[0]
kisi2008 = soccer2008[soccer2008["base_salary"] == soccer2008["base_salary"].max()]["last_name"].iloc[0]
kisi2009 = soccer2009[soccer2009["base_salary"] == soccer2009["base_salary"].max()]["last_name"].iloc[0]
kisi2010 = soccer2010[soccer2010["base_salary"] == soccer2010["base_salary"].max()]["last_name"].iloc[0]
kisi2011 = soccer2011[soccer2011["base_salary"] == soccer2011["base_salary"].max()]["last_name"].iloc[0]
kisi2012 = soccer2012[soccer2012["base_salary"] == soccer2012["base_salary"].max()]["last_name"].iloc[0]
kisi2013 = soccer2013[soccer2013["base_salary"] == soccer2013["base_salary"].max()]["last_name"].iloc[0]
kisi2014 = soccer2014[soccer2014["base_salary"] == soccer2014["base_salary"].max()]["last_name"].iloc[0]
kisi2015 = soccer2015[soccer2015["base_salary"] == soccer2015["base_salary"].max()]["last_name"].iloc[0]
kisi2016 = soccer2016[soccer2016["base_salary"] == soccer2016["base_salary"].max()]["last_name"].iloc[0]
kisi2017 = soccer2017[soccer2017["base_salary"] == soccer2017["base_salary"].max()]["last_name"].iloc[0]

# %%
#YILA GÖRE MAKSİMUM ÜCRET ALAN OYUNCU
fig_max_yıl = plt.figure(figsize = (15,10))
x =[ kisi2007,kisi2008,kisi2009,kisi2010,kisi2011,kisi2012,kisi2013,kisi2014,kisi2015,kisi2016,kisi2017]
y = [maks_maas2007,maks_maas2008,maks_maas2009,maks_maas2010,maks_maas2011,maks_maas2012,maks_maas2013,maks_maas2014,maks_maas2015,maks_maas2016,maks_maas2017]
plt.plot(x,y,color = "seagreen",marker = "o", lw = 3, markeredgecolor = "black", markerfacecolor = "black",markersize = 7,markeredgewidth = 5)
plt.title("Dönemin En Yüksek Ücretli Futbolcuları")
plt.xlabel("FUTBOLCULAR")
plt.ylabel("DÖNEMİN MAKSİMIM ÜCRETİ")
plt.show()
